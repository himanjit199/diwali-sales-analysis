# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
import seaborn as sns

# %%
#importing data set
df=pd.read_csv('Diwali Sales Data.CSV',encoding= 'unicode_escape')
df
#to avoid encoding error we use unicode_escape
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
#for data cleaning 
df.info()
#it gives the information of dataset like which column contains which type of datatype,is there any null vlaues etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#to delete unnecessary columns
df.drop(['Status','unnamed1'],axis=1, inplace=True)

# %%
df.shape # we can compare with result that two columns are deleted.
# Out:
# (11251, 13)

# %%
pd.isnull(df).sum() # it gives the sum of null data present in the dataset.
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# for drop null values
df.dropna(inplace=True)

# %%
#for checking
pd.isnull(df).sum() # here all null values are got replaced.
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
# we want to change datatype of Amount column to int
df['Amount']=df['Amount'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int32
# dtypes: int32(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# DATA CLEANING PROCESS IS DONE . SOME BASIC PANDAS DATA CLEANING OPERATIONS ARE DONE.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # FOR GENDER

# %%
ax=sns.countplot(x='Gender',data=df)

# %%
sales_gen= df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Gender',y='Amount', data=sales_gen)

# %% [markdown]
# From above graph we can say that most of the  buyers are females and even the purcahsing power of the females are also more than men.

# %% [markdown]
# # FOR AGE

# %%
ax=sns.countplot(x='Age Group',data=df,hue='Gender')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#total amount vs age group
sales_age=df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
se=sns.barplot(x='Age Group',y='Amount',data= sales_age)

# %% [markdown]
# From above graph we can see that most of the buyers are female at 26-35 years age group.

# %% [markdown]
# # FOR STATE

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
sns.countplot(x='Orders',hue='State',data=df)
sns.set(rc={'figure.figsize':(50,5)})

# %%
c=sns.barplot(data=df,x='State',y='Orders')
for bars in c.containers:
    c.bar_label(bars)
sns.set(rc={'figure.figsize':(20,10)})

# %%
#total amount vs state
sales_state= df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
ax=sns.barplot(x='State',y='Amount',data=sales_state)
sns.set(rc={'figure.figsize':(20,8)})

# %% [markdown]
# hence most buyers present in UP,Maharastra and Karnataka and their purcahsing powers are also ranked 1st, 2nd and 3rd respectively.

# %% [markdown]
# # FOR MARITAL STATUS

# %%
ax= sns.countplot(data=df,x='Marital_Status')
sns.set(rc={'figure.figsize':(7,4)})
for bars in ax.containers:
    ax.bar_label(bars)
#df.columns

# %%
sales_status= df.groupby(['Marital_Status',"Gender"],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(data=sales_status,x='Marital_Status',y='Amount',hue="Gender")
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# Hence married female has more purchasing power than men.

# %% [markdown]
# # OCCUPATION

# %%
ax=sns.countplot(x='Occupation',data= df)
sns.set(rc={'figure.figsize':(10,3)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_occu= df.groupby(['Occupation'],as_index= False)['Amount'].sum().sort_values(by="Amount",ascending= False)
sns.barplot(data=sales_occu,x='Occupation',y='Amount')
sns.set(rc={'figure.figsize':(40,3)})

# %% [markdown]
# hence most purchasing power from people it sector.

# %% [markdown]
# # PRODUCT CATEGORY

# %%
ax=sns.countplot(data=df,x='Product_Category')
# df.columns
sns.set(rc={'figure.figsize':(20,30)})

# %%
sales_product=df.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(data=sales_product,x='Product_Category',y='Amount')
sns.set(rc={'figure.figsize':(40,30)})

# %% [markdown]
# from this analysis we can find though clothing has more order but amount spend more on food .

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category.
